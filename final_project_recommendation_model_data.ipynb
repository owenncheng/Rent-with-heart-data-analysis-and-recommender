# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# #data wragling

# %%
#rent = pd.read_csv('rental_data.csv')
#rent.head()

# %%
house = pd.read_csv('gpmedianrent.csv')
house.head()
# Out:
#    Unnamed: 0                                 Suburb  Year      Housing_Type  \
# 0           0  Albert Park-Middle Park-West St Kilda  2012   1 bedroom flats
# 1           1  Albert Park-Middle Park-West St Kilda  2012   2 bedroom flats
# 2           2  Albert Park-Middle Park-West St Kilda  2012  2 bedroom houses
# 3           3  Albert Park-Middle Park-West St Kilda  2012   3 bedroom flats
# 4           4  Albert Park-Middle Park-West St Kilda  2012  3 bedroom houses
#
#    Value
# 0  330.0
# 1  450.0
# 2  550.0
# 3  650.0
# 4  810.0

# %%
house[house['Suburb'] == 'Haddon']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Suburb, Year, Housing_Type, Value]
# Index: []

# %%
house['Suburb'] = house['Suburb'].apply(lambda x: x.lower())

# %%
house.head()
# Out:
#    Unnamed: 0                                 Suburb  Year      Housing_Type  \
# 0           0  albert park-middle park-west st kilda  2012   1 bedroom flats
# 1           1  albert park-middle park-west st kilda  2012   2 bedroom flats
# 2           2  albert park-middle park-west st kilda  2012  2 bedroom houses
# 3           3  albert park-middle park-west st kilda  2012   3 bedroom flats
# 4           4  albert park-middle park-west st kilda  2012  3 bedroom houses
#
#    Value
# 0  330.0
# 1  450.0
# 2  550.0
# 3  650.0
# 4  810.0

# %%
house = house.assign(Suburb=house['Suburb'].str.split('-')).explode('Suburb').reset_index(drop=True)

# %% [markdown]
# ## Bus data

# %%
bus = pd.read_csv('busStops.csv')
bus.head()
# Out:
#    Unnamed: 0  STOP_ID                                          STOP_NAME  \
# 0           0    23195                       Andrew St/Union St (Kilmore)
# 1           1    23197             Wellington Square SC/Queen St (Wallan)
# 2           2    23202              Aquamoves/Tom Collins Dr (Shepparton)
# 3           3    23224  West End Caravan Park/Murray Valley Hwy (Yarra...
# 4           4    23225                      Jane Rd/Fiona Dr (Yarrawonga)
#
#     LATITUDE   LONGITUDE ROUTEUSSP  \
# 0 -37.290492  144.952280       NaN
# 1 -37.412990  144.978019  Wallan 1
# 2 -36.386027  145.394445         9
# 3 -36.022176  145.977047       NaN
# 4 -36.006707  146.025958       NaN
#
#                                         geometry      Suburb  \
# 0   POINT (2495769.6887600096 2467766.246883573)     Kilmore
# 1   POINT (2498054.827065963 2454173.5399368964)      Wallan
# 2  POINT (2535387.5811779075 2568052.8725087643)  Shepparton
# 3  POINT (2588067.9061623234 2608046.0027186014)  Yarrawonga
# 4    POINT (2592494.8952992545 2609715.94715723)  Yarrawonga
#
#                                Station_Name
# 0                       Andrew St/Union St
# 1            Wellington Square SC/Queen St
# 2                 Aquamoves/Tom Collins Dr
# 3  West End Caravan Park/Murray Valley Hwy
# 4                         Jane Rd/Fiona Dr

# %%
bus = bus.loc[:,["STOP_ID", "Suburb"]]
bus.head
# Out:
# <bound method NDFrame.head of       STOP_ID            Suburb
# 0       23195           Kilmore
# 1       23197            Wallan
# 2       23202        Shepparton
# 3       23224        Yarrawonga
# 4       23225        Yarrawonga
# ...       ...               ...
# 6738      536            Haddon
# 6739     6285             Nilma
# 6740       63  Ballarat Central
# 6741     7009           Marengo
# 6742       82  Ballarat Central
#
# [6743 rows x 2 columns]>

# %%
bus['Suburb'] = bus['Suburb'].apply(lambda x: x.lower())

# %%
bus.head()
# Out:
#    STOP_ID      Suburb
# 0    23195     kilmore
# 1    23197      wallan
# 2    23202  shepparton
# 3    23224  yarrawonga
# 4    23225  yarrawonga

# %%
gpbus = bus.groupby(by="Suburb").count().reset_index()
gpbus=gpbus[gpbus['Suburb']!= 'albury - nsw']

# %%
gpbus['Suburb'] = gpbus['Suburb'].replace({'3219':'east geelong'})
gpbus['Suburb'] = gpbus['Suburb'].replace({'3220':'south geelong'})
gpbus['Suburb'] = gpbus['Suburb'].replace({'3350':'nerrina'})

# %%
gpbus = gpbus.rename(columns={'STOP_ID': 'No_of_bus_stop'})

# %%
gpbus.head(10)
# Out:
#            Suburb  No_of_bus_stop
# 0    east geelong              12
# 1   south geelong              54
# 2         nerrina              26
# 3    aireys inlet               4
# 5       alexandra               2
# 6       alfredton              44
# 7      allansford               7
# 8           alvie               1
# 9    amphitheatre               2
# 10       anderson               1

# %% [markdown]
# ## station data

# %%
station = pd.read_csv('station_data.csv')
station.head()
# Out:
#    Unnamed: 0  STOP_ID                                          STOP_NAME  \
# 0           0    19970             Royal Park Railway Station (Parkville)
# 1           1    19971  Flemington Bridge Railway Station (North Melbo...
# 2           2    19972         Macaulay Railway Station (North Melbourne)
# 3           3    19973   North Melbourne Railway Station (West Melbourne)
# 4           4    19974        Clifton Hill Railway Station (Clifton Hill)
#
#     LATITUDE   LONGITUDE TICKETZONE  \
# 0 -37.781193  144.952301          1
# 1 -37.788140  144.939323          1
# 2 -37.794267  144.936166          1
# 3 -37.807419  144.942570          1
# 4 -37.788657  144.995417          1
#
#                                            ROUTEUSSP  \
# 0                                            Upfield
# 1                                            Upfield
# 2                                            Upfield
# 3  Flemington,Sunbury,Upfield,Werribee,Williamsto...
# 4                                 Mernda,Hurstbridge
#
#                                         geometry           Suburb  \
# 0   POINT (2495798.8483493025 2413310.211043857)        Parkville
# 1    POINT (2494656.139461309 2412538.540406987)  North Melbourne
# 2  POINT (2494378.5109065063 2411858.3440139396)  North Melbourne
# 3   POINT (2494943.4098035772 2410399.010290851)   West Melbourne
# 4    POINT (2499596.850108406 2412482.847753912)     Clifton Hill
#
#                         Station_Name
# 0         Royal Park Railway Station
# 1  Flemington Bridge Railway Station
# 2           Macaulay Railway Station
# 3    North Melbourne Railway Station
# 4       Clifton Hill Railway Station

# %%
station = station.loc[:,["STOP_ID", "Suburb"]]

# %%
station['Suburb'] = station['Suburb'].apply(lambda x: x.lower())

# %%
station.head()
# Out:
#    STOP_ID           Suburb
# 0    19970        parkville
# 1    19971  north melbourne
# 2    19972  north melbourne
# 3    19973   west melbourne
# 4    19974     clifton hill

# %%
gpstation = station.groupby(by="Suburb").count().reset_index()

# %%
gpstation = gpstation.rename(columns={'STOP_ID': 'No_of_train_station'})

# %%
gpstation.head()
# Out:
#        Suburb  No_of_train_station
# 0  abbotsford                    2
# 1  alphington                    1
# 2      altona                    2
# 3    armadale                    2
# 4  ascot vale                    1

# %% [markdown]
# ##Charity

# %%
charity = pd.read_csv('charity_v2.csv')

# %%
charity = charity.rename(columns={'Town_City': 'Suburb'})

# %%
charity.head()
# Out:
#    Unnamed: 0          ABN                  Charity_Legal_Name Address_Type  \
# 0           0  11003429338                          ISCAST LTD     Business
# 1           1  11004857827  Austin Medical Research Foundation     Business
# 2           2  11005151771             Braemar College Limited     Business
# 3           3  11005583960              Odyssey House Victoria     Business
# 4           4  11007434362           Alphington Grammar School     Business
#
#                   Address_Line_1       Suburb     State Postcode    Country  \
# 0                      PO Box 40  Forest Hill  Victoria     3131  Australia
# 1  Austin & Repat Medical Centre   Heidelberg  Victoria     3084  Australia
# 2        1499 MOUNT MACEDON ROAD      WOODEND       VIC     3442  Australia
# 3                  660 Bridge Rd     Richmond  Victoria     3121  Australia
# 4         18 Old Heidelberg Road   ALPHINGTON       VIC     3078  Australia
#
#                Charity_Website  ... People_at_risk_of_homelessness  \
# 0            http://iscast.org  ...                            NaN
# 1  http://www.austinmrf.org.au  ...                            NaN
# 2       www.braemar.vic.edu.au  ...                            NaN
# 3          www.odyssey.org.au/  ...                            NaN
# 4    www.alphington.vic.edu.au  ...                            NaN
#
#   People_with_Chronic_Illness People_with_Disabilities  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#    Pre_Post_Release_Offenders Rural_Regional_Remote_Communities  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
#
#   Unemployed_Person Veterans_or_their_families Victims_of_crime  \
# 0               NaN                        NaN              NaN
# 1               NaN                        NaN              NaN
# 2               NaN                        NaN              NaN
# 3               NaN                        NaN              NaN
# 4               NaN                        NaN              NaN
#
#   Victims_of_Disasters Youth
# 0                  NaN     Y
# 1                  NaN   NaN
# 2                  NaN     Y
# 3                  NaN   NaN
# 4                  NaN     Y
#
# [5 rows x 50 columns]

# %%
charity.columns
# Out:
# Index(['Unnamed: 0', 'ABN', 'Charity_Legal_Name', 'Address_Type',
#        'Address_Line_1', 'Suburb', 'State', 'Postcode', 'Country',
#        'Charity_Website', 'Registration_Date', 'Date_Organisation_Established',
#        'Charity_Size', 'Number_of_Responsible_Persons', 'Financial_Year_End',
#        'Operates_in_VIC', 'HPC', 'Advancing_Education', 'Advancing_Health',
#        'Promoting_or_protecting_human_rights',
#        'Purposes_beneficial_to_ther_general_public_and_other_analogous',
#        'Promoting_reconciliation__mutual_respect_and_tolerance',
#        'Advancing_Religion', 'Advancing_social_or_public_welfare',
#        'Aboriginal_or_TSI', 'Adults', 'Aged_Persons', 'Children',
#        'Communities_Overseas', 'Early_Childhood', 'Ethnic_Groups', 'Families',
#        'Females', 'Financially_Disadvantaged', 'Gay_Lesbian_Bisexual',
#        'General_Community_in_Australia', 'Males',
#        'Migrants_Refugees_or_Asylum_Seekers', 'Other_Beneficiaries',
#        'Other_Charities', 'People_at_risk_of_homelessness',
#        'People_with_Chronic_Illness', 'People_with_Disabilities',
#        'Pre_Post_Release_Offenders', 'Rural_Regional_Remote_Communities',
#        'Unemployed_Person', 'Veterans_or_their_families', 'Victims_of_crime',
#        'Victims_of_Disasters', 'Youth'],
#       dtype='object')

# %% [markdown]
# ###Child charity

# %%
childcharity = charity.loc[(charity['Children'] == 'Y') | (charity['Early_Childhood'] == 'Y'),['ABN','Suburb']]

# %%
childcharity.head()

# %%
childcharity = childcharity.dropna()
childcharity

# %%
childcharity['Suburb'] = childcharity['Suburb'].apply(lambda x: x.lower())

# %%
childcharity

# %%
gpchildcharity = childcharity.groupby(by="Suburb").count().reset_index()
gpchildcharity = gpchildcharity.rename(columns={'ABN': 'No_of_child_charity'})
gpchildcharity.head()

# %%
gpchildcharity['Suburb'] = gpchildcharity['Suburb'].replace({'73 grey street, st kilda west':'west st kilda'})
gpchildcharity['Suburb'] = gpchildcharity['Suburb'].replace({'315 aqueduct road':'st helena'})

# %%
gpchildcharity.head()
# Out:
#             Suburb  No_of_child_charity
# 0        st helena                    1
# 1    west st kilda                    1
# 2       abbotsford                   18
# 3  abeckett street                    2
# 4       aberfeldie                    4

# %% [markdown]
# ##charity for adult, single mother, families

# %%
charity.head()
# Out:
#    Unnamed: 0          ABN                  Charity_Legal_Name Address_Type  \
# 0           0  11003429338                          ISCAST LTD     Business
# 1           1  11004857827  Austin Medical Research Foundation     Business
# 2           2  11005151771             Braemar College Limited     Business
# 3           3  11005583960              Odyssey House Victoria     Business
# 4           4  11007434362           Alphington Grammar School     Business
#
#                   Address_Line_1       Suburb     State Postcode    Country  \
# 0                      PO Box 40  Forest Hill  Victoria     3131  Australia
# 1  Austin & Repat Medical Centre   Heidelberg  Victoria     3084  Australia
# 2        1499 MOUNT MACEDON ROAD      WOODEND       VIC     3442  Australia
# 3                  660 Bridge Rd     Richmond  Victoria     3121  Australia
# 4         18 Old Heidelberg Road   ALPHINGTON       VIC     3078  Australia
#
#                Charity_Website  ... People_at_risk_of_homelessness  \
# 0            http://iscast.org  ...                            NaN
# 1  http://www.austinmrf.org.au  ...                            NaN
# 2       www.braemar.vic.edu.au  ...                            NaN
# 3          www.odyssey.org.au/  ...                            NaN
# 4    www.alphington.vic.edu.au  ...                            NaN
#
#   People_with_Chronic_Illness People_with_Disabilities  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#    Pre_Post_Release_Offenders Rural_Regional_Remote_Communities  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
#
#   Unemployed_Person Veterans_or_their_families Victims_of_crime  \
# 0               NaN                        NaN              NaN
# 1               NaN                        NaN              NaN
# 2               NaN                        NaN              NaN
# 3               NaN                        NaN              NaN
# 4               NaN                        NaN              NaN
#
#   Victims_of_Disasters Youth
# 0                  NaN     Y
# 1                  NaN   NaN
# 2                  NaN     Y
# 3                  NaN   NaN
# 4                  NaN     Y
#
# [5 rows x 50 columns]

# %%
adultcharity = charity.loc[(charity['Adults'] == 'Y') | (charity['Families'] == 'Y') | (charity['Females'] == 'Y')| (charity['Financially_Disadvantaged'] == 'Y')| (charity['People_at_risk_of_homelessness'] == 'Y')| (charity['Unemployed_Person'] == 'Y'),['ABN','Suburb']]

# %%
adultcharity = adultcharity.dropna()

# %%
adultcharity['Suburb'] = adultcharity['Suburb'].apply(lambda x: x.lower())

# %%
adultcharity.head()
# Out:
#             ABN       Suburb
# 0   11003429338  forest hill
# 3   11005583960     richmond
# 4   11007434362   alphington
# 8   11037728335      morwell
# 11  11064494169       albury

# %%
gpadultcharity = adultcharity.groupby(by="Suburb").count().reset_index()
gpadultcharity = gpadultcharity.rename(columns={'ABN': 'No_of_adult_charity'})

# %%
gpadultcharity['Suburb'] = gpadultcharity['Suburb'].replace({'73 grey street, st kilda west':'west st kilda'})

# %%
gpadultcharity.head()
# Out:
#             Suburb  No_of_adult_charity
# 0    west st kilda                    1
# 1       abbotsford                   27
# 2  abeckett street                    2
# 3       aberfeldie                    4
# 4     acacia ridge                    1

# %% [markdown]
# ##school data

# %%
school = pd.read_csv('school.csv',sep=",", encoding='mac_roman')
school.head()
# Out:
#   Education_Sector  Entity_Type  SCHOOL_NO  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# 3  40 Anderson Street            NaN       Avenel           VIC  ...
# 4  5-11 Forbes Street            NaN   Warrandyte           VIC  ...
#
#    Postal_Address_Line_1 Postal_Address_Line_2 Postal_Town Postal_State  \
# 0      21 Thomson Street                   NaN    ALBERTON          VIC
# 1           Frank Street                   NaN  ALLANSFORD          VIC
# 2             P O Box 12                   NaN       AVOCA          VIC
# 3     40 Anderson Street                   NaN      AVENEL          VIC
# 4     5-11 Forbes Street                   NaN  WARRANDYTE          VIC
#
#   Postal_Postcode  Full_Phone_No LGA_ID         LGA_Name          X         Y
# 0            3971   03 5183 2412    681   Wellington (S)  146.66660 -38.61771
# 1            3277   03 5565 1382    673  Warrnambool (C)  142.59039 -38.38628
# 2            3467   03 5465 3176    599     Pyrenees (S)  143.47565 -37.08450
# 3            3664   03 5796 2264    643  Strathbogie (S)  145.23472 -36.90137
# 4            3113   03 9844 3537    421   Manningham (C)  145.21398 -37.74268
#
# [5 rows x 21 columns]

# %%
school['School_Type'].unique()
# Out:
# array(['Primary', 'Pri/Sec', 'Special', 'Camp', 'Secondary', 'Language'],
#       dtype=object)

# %%
school = school.loc[:,["School_Type","Address_Town","School_Name"]]

# %%
school
# Out:
#      School_Type        Address_Town                             School_Name
# 0        Primary            Alberton                 Alberton Primary School
# 1        Primary          Allansford  Allansford and District Primary School
# 2        Primary               Avoca                    Avoca Primary School
# 3        Primary              Avenel                   Avenel Primary School
# 4        Primary          Warrandyte               Warrandyte Primary School
# ...          ...                 ...                                     ...
# 2294     Primary  NARRE WARREN NORTH                Lysterfield Lake College
# 2295   Secondary        SOUTH MORANG                    Plenty River College
# 2296     Primary           MICKLEHAM      Holy Cross Catholic Primary School
# 2297     Primary  NARRE WARREN NORTH                   Sidrah Gardens School
# 2298   Secondary      FERNTREE GULLY     Mountain District Community College
#
# [2299 rows x 3 columns]

# %%
school = school.dropna()
school = school.rename(columns={'Address_Town': 'Suburb'})
school['Suburb'] = school['Suburb'].apply(lambda x: x.lower())

# %%
school.head()
# Out:
#   School_Type      Suburb                             School_Name
# 0     Primary    alberton                 Alberton Primary School
# 1     Primary  allansford  Allansford and District Primary School
# 2     Primary       avoca                    Avoca Primary School
# 3     Primary      avenel                   Avenel Primary School
# 4     Primary  warrandyte               Warrandyte Primary School

# %%
gpschool = school.groupby(by=["Suburb","School_Type"])['School_Name'].count().reset_index()

# %%
gpschool = gpschool.rename(columns={'School_Name': 'No_of_school'})

# %%
gpschool['School_Type'].unique()
# Out:
# array(['Pri/Sec', 'Primary', 'Secondary', 'Special', 'Camp', 'Language'],
#       dtype=object)

# %%
gpschool = gpschool[(gpschool['School_Type'] == 'Pri/Sec') | (gpschool['School_Type'] == 'Primary') | (gpschool['School_Type'] == 'Secondary')]

# %%
gpschool
# Out:
#             Suburb School_Type  No_of_school
# 0       abbotsford     Pri/Sec             1
# 1       abbotsford     Primary             1
# 2       aberfeldie     Primary             1
# 3       aberfeldie   Secondary             1
# 4          aintree     Primary             1
# ...            ...         ...           ...
# 1434           yea   Secondary             1
# 1435        yering     Primary             1
# 1436        yinnar     Primary             1
# 1437  yinnar south     Primary             1
# 1438       zeerust     Primary             1
#
# [1332 rows x 3 columns]

# %%
gpschool['No_of_school'].unique()
# Out:
# array([1, 2, 3, 4, 6, 5, 7, 9, 8])

# %% [markdown]
# ##merge dataframe

# %%
merge1 = house.merge(gpchildcharity, on='Suburb', how='left')

# %%
merge2 = merge1.merge(gpadultcharity, on='Suburb', how='left')

# %%
merge3 = merge2.merge(gpbus, on='Suburb', how='left')

# %%
merge4 = merge3.merge(gpstation, on='Suburb', how='left')

# %%
merge5 = merge4.merge(gpschool, on='Suburb', how='left')

# %%
merge5.head()
# Out:
#    Unnamed: 0         Suburb  Year     Housing_Type  Value  \
# 0           0    albert park  2012  1 bedroom flats  330.0
# 1           0    albert park  2012  1 bedroom flats  330.0
# 2           0    middle park  2012  1 bedroom flats  330.0
# 3           0  west st kilda  2012  1 bedroom flats  330.0
# 4           1    albert park  2012  2 bedroom flats  450.0
#
#    No_of_child_charity  No_of_adult_charity  No_of_bus_stop  \
# 0                 13.0                 17.0             NaN
# 1                 13.0                 17.0             NaN
# 2                  4.0                  5.0             NaN
# 3                  1.0                  1.0             NaN
# 4                 13.0                 17.0             NaN
#
#    No_of_train_station School_Type  No_of_school
# 0                  NaN     Primary           2.0
# 1                  NaN   Secondary           1.0
# 2                  NaN     Primary           1.0
# 3                  NaN         NaN           NaN
# 4                  NaN     Primary           2.0

# %%
merge5=merge5.fillna(0)

# %%
merge5 = merge5.iloc[:,1:]

# %%
merge5.to_csv('train.csv')
